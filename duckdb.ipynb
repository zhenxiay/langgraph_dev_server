# %% [markdown]
# ### Set up DB connection

# %%
import duckdb
con = duckdb.connect(database='output.duckdb', read_only=True)

# %% [markdown]
# ### Read Data

# %%
con.sql("SELECT * FROM result_sentiment_analysis LIMIT 10")

# %% [markdown]
# ### Export Data

# %%
con.sql("SELECT * FROM result_sentiment_analysis").df().to_excel("sentiment_analysis_results.xlsx", index=False)

# %% [markdown]
# ### Close Connection

# %%
con.close()
